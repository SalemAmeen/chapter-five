# %% [markdown]
# Load the testing data (Unseen data)

# %%
import numpy as np
import time
import matplotlib.pyplot as plt
import matplotlib.gridspec as gridspec
# %matplotlib inline
from IPython.display import set_matplotlib_formats
set_matplotlib_formats('png', 'pdf')
from keras.models import Sequential
from keras.layers import Dense
from keras.layers import Dropout
import numpy
from sklearn import metrics
from sklearn import datasets
from sklearn.metrics import accuracy_score, roc_curve, auc
import sys
sys.path.append("./titanc")
plt.rcParams['figure.figsize'] = (15, 6)
# Out:
# Using TensorFlow backend.

# %% [markdown]
# # Load the Data

# %%
X_train = np.load('./titanc/X_train.npy')
y_train = np.load('./titanc/y_train.npy')
X_test = np.load('./titanc/X_test.npy')
y_test = np.load('./titanc/y_test.npy')

print 'Number of training examples',len(X_train)
print 'Number of validation examples',len(X_test)
print 'Number of testing examples',len(X_test)
# Out:
# Number of training examples 712
# Number of validation examples 179
# Number of testing examples 179

# %% [markdown]
# # Initialize the classifiers as the training time

# %%
from sklearn.neighbors import KNeighborsClassifier
clf_neigh = KNeighborsClassifier(n_neighbors=5)
clf_neigh.fit(X_train, y_train)
from sklearn.svm import LinearSVC
clf_svm_linear = LinearSVC(C=10.0)
clf_svm_linear.fit(X_train, y_train)
from sklearn.svm import SVC
clf_svm = SVC(C=5.0, kernel='rbf')
clf_svm.fit(X_train, y_train)
from sklearn.tree import DecisionTreeClassifier
clf_dt = DecisionTreeClassifier(min_samples_split=2)
clf_dt.fit(X_train, y_train)
from sklearn.tree import DecisionTreeClassifier
clf_dt_IG = DecisionTreeClassifier(criterion='entropy', min_samples_split=2)
clf_dt_IG.fit(X_train, y_train)
from sklearn.ensemble import BaggingClassifier
from sklearn.neighbors import KNeighborsClassifier
clf_dt_BGKN = BaggingClassifier(KNeighborsClassifier(n_neighbors=5),
                             max_samples=0.5, max_features=0.5)
clf_dt_BGKN.fit(X_train, y_train)
from sklearn.ensemble import BaggingClassifier
from sklearn.tree import DecisionTreeClassifier
clf_dt_BGDT = BaggingClassifier(DecisionTreeClassifier(criterion='entropy', min_samples_split=2),
                             max_samples=0.5, max_features=0.5)
clf_dt_BGDT.fit(X_train, y_train)
from sklearn.ensemble import RandomForestClassifier
clf_dt_RF = RandomForestClassifier()
#Training
start_time = time.time()
clf_dt_RF.fit(X_train, y_train)
from sklearn.ensemble import AdaBoostClassifier
clf_dt_AD = AdaBoostClassifier()
clf_dt_AD.fit(X_train, y_train)
from sklearn.naive_bayes import GaussianNB
clf_NB = GaussianNB()
clf_NB.fit(X_train, y_train)
from sklearn.discriminant_analysis import LinearDiscriminantAnalysis
clf_dt_LDA = LinearDiscriminantAnalysis()
clf_dt_LDA.fit(X_train, y_train)
from sklearn.discriminant_analysis import QuadraticDiscriminantAnalysis
clf_dt_QDA = QuadraticDiscriminantAnalysis()
clf_dt_QDA.fit(X_train, y_train)
# Out:
# QuadraticDiscriminantAnalysis(priors=None, reg_param=0.0,
#                store_covariances=False, tol=0.0001)

# %%
import seaborn as sns
import numpy as np
from sklearn.cross_validation import train_test_split
from keras.models import Sequential
from keras.layers import Dense, Dropout
from keras.regularizers import l2
from keras.utils import np_utils
labelsTrain = np_utils.to_categorical(y_train)
labelsTest = np_utils.to_categorical(y_test) 
model = Sequential()
model.add(Dense(60,
                input_shape=(9,), 
                activation="relu",
                W_regularizer=l2(0.001)))
#model.add(Dropout(0.5))
model.add(Dense(2, activation="softmax"))
model.load_weights('/Users/salemameen/Desktop/banditsbook/python_Titanic/titancModelbest.hdf5')
model.compile(loss='categorical_crossentropy',
              metrics=['accuracy'],
              optimizer='adam')

# %%
# MAB_NN(4%REMOVED) MODEL1    1               
model1 = Sequential()
model1.add(Dense(60,
                input_shape=(9,), 
                activation="relu",
                W_regularizer=l2(0.001)))
#model.add(Dropout(0.5))
model1.add(Dense(2, activation="softmax"))
model1.load_weights('/Users/salemameen/Desktop/banditsbook/python_Titanic/IrisUCB1/spam0.hdf5')
model1.compile(loss='categorical_crossentropy',
              metrics=['accuracy'],
              optimizer='adam')

# %%
# MAB_NN(6.67%REMOVED) MODEL2 4
model2 = Sequential()
model2.add(Dense(60,
                input_shape=(9,), 
                activation="relu",
                W_regularizer=l2(0.001)))
#model.add(Dropout(0.5))
model2.add(Dense(2, activation="softmax"))
model2.load_weights('/Users/salemameen/Desktop/banditsbook/python_Titanic/IrisUCB1/spam3.hdf5')
model2.compile(loss='categorical_crossentropy',
              metrics=['accuracy'],
              optimizer='adam')

# %%
# MAB_NN(30%REMOVED) MODEL3 18
model3 = Sequential()
model3.add(Dense(60,
                input_shape=(9,), 
                activation="relu",
                W_regularizer=l2(0.001)))
#model.add(Dropout(0.5))
model3.add(Dense(2, activation="softmax"))
model3.load_weights('/Users/salemameen/Desktop/banditsbook/python_Titanic/IrisUCB1/spam17.hdf5')
model3.compile(loss='categorical_crossentropy',
              metrics=['accuracy'],
              optimizer='adam')

# %% [markdown]
# ## Deployment Time

# %%
start_time = time.time()
y_pred_neigh = clf_neigh.predict(X_test)
print("The time of KNN is           %s seconds" % (time.time() - start_time))
# Linear SVM 
start_time = time.time()
y_pred_svm_linear = clf_svm_linear.predict(X_test)
print("The time of LSVM is          %s seconds " % (time.time() - start_time))
# SVM kernel='rbf'
start_time = time.time()
y_pred_svm = clf_svm.predict(X_test)
print("The time of SVM is           %s seconds " % (time.time() - start_time))
# DT with gini
start_time = time.time()
y_pred_gtgini = clf_dt.predict(X_test)
print("The time of DT_gini is       %s seconds " % (time.time() - start_time))
# DT with entorpy
start_time = time.time()
y_pred_dt_IG = clf_dt_IG.predict(X_test)
print("The time of DT is            %s seconds" % (time.time() - start_time))
# Bagging with Knn
start_time = time.time()
y_pred_dt_BGKN = clf_dt_BGKN.predict(X_test)
print("The time of Bagging Knn is   %s seconds" % (time.time() - start_time))
# Bagging with DT with gini
start_time = time.time()
y_pred_dt_BGDT = clf_dt_BGDT.predict(X_test)
print("The time of Bagging DT is    %s seconds " % (time.time() - start_time))
# Random Forest with DT with gini
start_time = time.time()
y_pred_dt_RF = clf_dt_RF.predict(X_test)
print("The time of Random Forest is %s seconds " % (time.time() - start_time))
# Ada Boost
start_time = time.time()
y_pred_dt_AD = clf_dt_AD.predict(X_test)
print("The time of Ada Boost is     %s seconds " % (time.time() - start_time))
# Naive Bayes
start_time = time.time()
y_pred_NB = clf_NB.predict(X_test)
print("The time of Naive Bayes is   %s seconds " % (time.time() - start_time))
# LDA
start_time = time.time()
y_pred_dt_LDA = clf_dt_LDA.predict(X_test)
print("The time of LDA is           %s seconds " % (time.time() - start_time))
# QDA
start_time = time.time()
y_pred_dt_QDA = clf_dt_QDA.predict(X_test)
print("The time of QDA is           %s seconds " % (time.time() - start_time))
# NN
start_time = time.time()
y_pred_NN = model.predict_classes(X_test)
print("The time of NN is            %s seconds " % (time.time() - start_time))
# NN 4% removed neurals
start_time = time.time()
y_pred_NN1 = model1.predict_classes(X_test)
print("The time of 1.67 Removed is %s seconds " % (time.time() - start_time))
# NN 6.67% removed neurals
start_time = time.time()
y_pred_NN2 = model2.predict_classes(X_test)
print("The time of NN6.67 Removed is %s seconds " % (time.time() - start_time))
# NN 30% removed neurals
start_time = time.time()
y_pred_NN3 = model3.predict_classes(X_test)
print("The time of NN30 Removed is  %s seconds " % (time.time() - start_time))
# Out:
# The time of KNN is           0.00186109542847 seconds
# The time of LSVM is          0.00029993057251 seconds
# The time of SVM is           0.00138807296753 seconds
# The time of DT_gini is       0.000144004821777 seconds
# The time of DT is            0.000127077102661 seconds
# The time of Bagging Knn is   0.00632786750793 seconds
# The time of Bagging DT is    0.000916004180908 seconds
# The time of Random Forest is 0.00106692314148 seconds
# The time of Ada Boost is     0.00410509109497 seconds
# The time of Naive Bayes is   0.000289916992188 seconds
# The time of LDA is           0.000173091888428 seconds
# The time of QDA is           0.000289916992188 seconds
# 179/179 [==============================] - 0s
# The time of NN is            0.0241928100586 seconds
# 179/179 [==============================] - 0s
# The time of 1.67 Removed is 0.0235180854797 seconds
# 179/179 [==============================] - 0s
# The time of NN6.67 Removed is 0.0232489109039 seconds
# ...

# %% [markdown]
# # Accuracy of the models on Testing data

# %%
print "The accuracy of KNN:          \t", metrics.accuracy_score(y_test, y_pred_neigh)
print "The accuracy of LSVM:         \t", metrics.accuracy_score(y_test, y_pred_svm_linear)
print "The accuracy of SVM:          \t", metrics.accuracy_score(y_test, y_pred_svm)
print "The accuracy of DT_gini:      \t", metrics.accuracy_score(y_test, y_pred_gtgini)
print "The accuracy of DT_entorpy:   \t", metrics.accuracy_score(y_test, y_pred_dt_IG)
print "The accuracy of Bagging Knn:  \t", metrics.accuracy_score(y_test, y_pred_dt_BGKN)
print "The accuracy of Bagging DT:   \t", metrics.accuracy_score(y_test, y_pred_dt_BGDT)
print "The accuracy of Random Forest:\t", metrics.accuracy_score(y_test, y_pred_dt_RF)
print "The accuracy of Ada Boost:    \t", metrics.accuracy_score(y_test, y_pred_dt_AD)
print "The accuracy of Naive Bayes:  \t", metrics.accuracy_score(y_test, y_pred_NB)
print "The accuracy of LDA:          \t", metrics.accuracy_score(y_test, y_pred_dt_LDA)
print "The accuracy of QDA:          \t", metrics.accuracy_score(y_test, y_pred_dt_QDA)
print "The accuracy of NN:           \t", metrics.accuracy_score(y_test, y_pred_NN)
print "The accuracy of NN1.676R:    \t", metrics.accuracy_score(y_test, y_pred_NN1)
print "The accuracy of NN6.67R:     \t", metrics.accuracy_score(y_test, y_pred_NN2)
print "The accuracy of NN30R:        \t", metrics.accuracy_score(y_test, y_pred_NN3)
# Out:
# The accuracy of KNN:          	0.77094972067
# The accuracy of LSVM:         	0.77094972067
# The accuracy of SVM:          	0.782122905028
# The accuracy of DT_gini:      	0.631284916201
# The accuracy of DT_entorpy:   	0.743016759777
# The accuracy of Bagging Knn:  	0.759776536313
# The accuracy of Bagging DT:   	0.759776536313
# The accuracy of Random Forest:	0.748603351955
# The accuracy of Ada Boost:    	0.748603351955
# The accuracy of Naive Bayes:  	0.776536312849
# The accuracy of LDA:          	0.77094972067
# The accuracy of QDA:          	0.793296089385
# The accuracy of NN:           	0.782122905028
# The accuracy of NN1.676R:    	0.798882681564
# The accuracy of NN6.67R:     	0.804469273743
# The accuracy of NN30R:        	0.776536312849

# %% [markdown]
# # Precision, Recall, F1-score and Support on Testing data

# %%
print "\n==================================================================="
print " KNN:"
print metrics.classification_report(y_test, y_pred_neigh, target_names=['Died' , 'Survied'])

print "\n==================================================================="
print " LSVM:"
print metrics.classification_report(y_test, y_pred_svm_linear, target_names=['Died' , 'Survied'])

print "\n==================================================================="
print " SVM:"
print metrics.classification_report(y_test, y_pred_svm, target_names=['Died' , 'Survied'])

print "\n==================================================================="
print " DT_gini:"
print metrics.classification_report(y_test, y_pred_gtgini, target_names=['Died' , 'Survied'])


print "\n==================================================================="
print " DT_entorpy:"
print metrics.classification_report(y_test, y_pred_dt_IG, target_names=['Died' , 'Survied'])

print "\n==================================================================="
print " Bagging Knn:"
print metrics.classification_report(y_test, y_pred_dt_BGKN, target_names=['Died' , 'Survied'])


print "\n==================================================================="
print " Bagging DT:"
print metrics.classification_report(y_test, y_pred_dt_BGDT, target_names=['Died' , 'Survied'])

print "\n==================================================================="
print " Random Forest:"
print metrics.classification_report(y_test, y_pred_dt_RF, target_names=['Died' , 'Survied'])


print "\n==================================================================="
print " Ada Boost:"
print metrics.classification_report(y_test, y_pred_dt_AD, target_names=['Died' , 'Survied'])

print "\n==================================================================="
print " Naive Bayes:"
print metrics.classification_report(y_test, y_pred_NB, target_names=['Died' , 'Survied'])


print "\n==================================================================="
print " LDA:"
print metrics.classification_report(y_test, y_pred_dt_LDA, target_names=['Died' , 'Survied'])

print "\n==================================================================="
print " QDA:"
print metrics.classification_report(y_test, y_pred_dt_QDA, target_names=['Died' , 'Survied'])

print "\n==================================================================="
print " NN:"
print metrics.classification_report(y_test, y_pred_NN, target_names=['Died' , 'Survied'])

print "\n==================================================================="
print " NN1.67:"
print metrics.classification_report(y_test, y_pred_NN1, target_names=['Died' , 'Survied'])

print "\n==================================================================="
print " NN6.67:"
print metrics.classification_report(y_test, y_pred_NN2, target_names=['Died' , 'Survied'])

print "\n==================================================================="
print " NN30:"
print metrics.classification_report(y_test, y_pred_NN3, target_names=['Died' , 'Survied'])
# Out:
# ...
#  KNN:
#              precision    recall  f1-score   support
#
#        Died       0.80      0.81      0.81       106
#     Survied       0.72      0.71      0.72        73
#
# avg / total       0.77      0.77      0.77       179
#
#
# ...
#  LSVM:
#              precision    recall  f1-score   support
#
#        Died       0.79      0.84      0.81       106
#     Survied       0.74      0.67      0.71        73
#
# avg / total       0.77      0.77      0.77       179
#
#
# ...
#  SVM:
#              precision    recall  f1-score   support
#
#        Died       0.80      0.84      0.82       106
#     Survied       0.75      0.70      0.72        73
#
# avg / total       0.78      0.78      0.78       179
#
#
# ...
#  DT_gini:
#              precision    recall  f1-score   support
#
#        Died       0.74      0.58      0.65       106
#     Survied       0.54      0.70      0.61        73
#
# avg / total       0.66      0.63      0.63       179
#
#
# ...
#  DT_entorpy:
# ...

# %% [markdown]
# # Receiver Operating Characteristic

# %%
plt.rcParams['figure.figsize'] = (12, 10)
plt.figure(1)
plt.subplot(2,2,1)
false_positive_rate, true_positive_rate, thresholds = roc_curve(y_test, y_pred_neigh)
roc_auc = auc(false_positive_rate, true_positive_rate)
plt.title('Receiver Operating Characteristic knn')
plt.plot(false_positive_rate, true_positive_rate, 'b',
label='AUC = %0.2f'% roc_auc)
plt.legend(loc='lower right')
plt.plot([0,1],[0,1],'r--')
plt.xlim([-0.1,1.2])
plt.ylim([-0.1,1.2])
plt.ylabel('True Positive Rate')
plt.xlabel('False Positive Rate')
###############################################################################
plt.subplot(2,2,2)
false_positive_rate, true_positive_rate, thresholds = roc_curve(y_test, y_pred_svm_linear)
roc_auc = auc(false_positive_rate, true_positive_rate)
plt.title('Receiver Operating Characteristic SVM_linear')
plt.plot(false_positive_rate, true_positive_rate, 'b',
label='AUC = %0.2f'% roc_auc)
plt.legend(loc='lower right')
plt.plot([0,1],[0,1],'r--')
plt.xlim([-0.1,1.2])
plt.ylim([-0.1,1.2])
plt.ylabel('True Positive Rate')
plt.xlabel('False Positive Rate')
##############################################################################
plt.subplot(2,2,3)
false_positive_rate, true_positive_rate, thresholds = roc_curve(y_test, y_pred_svm)
roc_auc = auc(false_positive_rate, true_positive_rate)
plt.title('Receiver Operating Characteristic SVM')
plt.plot(false_positive_rate, true_positive_rate, 'b',
label='AUC = %0.2f'% roc_auc)
plt.legend(loc='lower right')
plt.plot([0,1],[0,1],'r--')
plt.xlim([-0.1,1.2])
plt.ylim([-0.1,1.2])
plt.ylabel('True Positive Rate')
plt.xlabel('False Positive Rate')
###############################################################################
plt.subplot(2,2,4)
false_positive_rate, true_positive_rate, thresholds = roc_curve(y_test, y_pred_gtgini)
roc_auc = auc(false_positive_rate, true_positive_rate)
plt.title('Receiver Operating Characteristic DT with gini')
plt.plot(false_positive_rate, true_positive_rate, 'b',
label='AUC = %0.2f'% roc_auc)
plt.legend(loc='lower right')
plt.plot([0,1],[0,1],'r--')
plt.xlim([-0.1,1.2])
plt.ylim([-0.1,1.2])
plt.ylabel('True Positive Rate')
plt.xlabel('False Positive Rate')
###############################################################################
##############################################################################
plt.figure(2)
plt.subplot(2,2,1)
false_positive_rate, true_positive_rate, thresholds = roc_curve(y_test, y_pred_dt_IG)
roc_auc = auc(false_positive_rate, true_positive_rate)
plt.title('Receiver Operating Characteristic DT with entorpy')
plt.plot(false_positive_rate, true_positive_rate, 'b',
label='AUC = %0.2f'% roc_auc)
plt.legend(loc='lower right')
plt.plot([0,1],[0,1],'r--')
plt.xlim([-0.1,1.2])
plt.ylim([-0.1,1.2])
plt.ylabel('True Positive Rate')
plt.xlabel('False Positive Rate')
################################################################################
plt.subplot(2,2,2)
false_positive_rate, true_positive_rate, thresholds = roc_curve(y_test, y_pred_dt_BGKN)
roc_auc = auc(false_positive_rate, true_positive_rate)
plt.title('Receiver Operating Characteristic Bagging DT')
plt.plot(false_positive_rate, true_positive_rate, 'b',
label='AUC = %0.2f'% roc_auc)
plt.legend(loc='lower right')
plt.plot([0,1],[0,1],'r--')
plt.xlim([-0.1,1.2])
plt.ylim([-0.1,1.2])
plt.ylabel('True Positive Rate')
plt.xlabel('False Positive Rate')
###############################################################################
plt.subplot(2,2,3)
false_positive_rate, true_positive_rate, thresholds = roc_curve(y_test, y_pred_dt_RF)
roc_auc = auc(false_positive_rate, true_positive_rate)
plt.title('Receiver Operating Characteristic Random Forest')
plt.plot(false_positive_rate, true_positive_rate, 'b',
label='AUC = %0.2f'% roc_auc)
plt.legend(loc='lower right')
plt.plot([0,1],[0,1],'r--')
plt.xlim([-0.1,1.2])
plt.ylim([-0.1,1.2])
plt.ylabel('True Positive Rate')
plt.xlabel('False Positive Rate')
###############################################################################
plt.subplot(2,2,4)
false_positive_rate, true_positive_rate, thresholds = roc_curve(y_test, y_pred_dt_AD)
roc_auc = auc(false_positive_rate, true_positive_rate)
plt.title('Receiver Operating Characteristic Ada Boost')
plt.plot(false_positive_rate, true_positive_rate, 'b',
label='AUC = %0.2f'% roc_auc)
plt.legend(loc='lower right')
plt.plot([0,1],[0,1],'r--')
plt.xlim([-0.1,1.2])
plt.ylim([-0.1,1.2])
plt.ylabel('True Positive Rate')
plt.xlabel('False Positive Rate')
###############################################################################
###############################################################################
##############################################################################
plt.figure(3)
plt.subplot(2,2,1)
false_positive_rate, true_positive_rate, thresholds = roc_curve(y_test, y_pred_NB)
roc_auc = auc(false_positive_rate, true_positive_rate)
plt.title('Receiver Operating Characteristic NB')
plt.plot(false_positive_rate, true_positive_rate, 'b',
label='AUC = %0.2f'% roc_auc)
plt.legend(loc='lower right')
plt.plot([0,1],[0,1],'r--')
plt.xlim([-0.1,1.2])
plt.ylim([-0.1,1.2])
plt.ylabel('True Positive Rate')
plt.xlabel('False Positive Rate')
################################################################################
plt.subplot(2,2,2)
false_positive_rate, true_positive_rate, thresholds = roc_curve(y_test, y_pred_dt_LDA)
roc_auc = auc(false_positive_rate, true_positive_rate)
plt.title('Receiver Operating Characteristic LDA')
plt.plot(false_positive_rate, true_positive_rate, 'b',
label='AUC = %0.2f'% roc_auc)
plt.legend(loc='lower right')
plt.plot([0,1],[0,1],'r--')
plt.xlim([-0.1,1.2])
plt.ylim([-0.1,1.2])
plt.ylabel('True Positive Rate')
plt.xlabel('False Positive Rate')
###############################################################################
plt.subplot(2,2,3)
false_positive_rate, true_positive_rate, thresholds = roc_curve(y_test, y_pred_dt_QDA)
roc_auc = auc(false_positive_rate, true_positive_rate)
plt.title('Receiver Operating Characteristic LDA')
plt.plot(false_positive_rate, true_positive_rate, 'b',
label='AUC = %0.2f'% roc_auc)
plt.legend(loc='lower right')
plt.plot([0,1],[0,1],'r--')
plt.xlim([-0.1,1.2])
plt.ylim([-0.1,1.2])
plt.ylabel('True Positive Rate')
plt.xlabel('False Positive Rate')
###############################################################################
plt.subplot(2,2,4)
false_positive_rate, true_positive_rate, thresholds = roc_curve(y_test, y_pred_NN)
roc_auc = auc(false_positive_rate, true_positive_rate)
plt.title('Receiver Operating Characteristic NN')
plt.plot(false_positive_rate, true_positive_rate, 'b',
label='AUC = %0.2f'% roc_auc)
plt.legend(loc='lower right')
plt.plot([0,1],[0,1],'r--')
plt.xlim([-0.1,1.2])
plt.ylim([-0.1,1.2])
plt.ylabel('True Positive Rate')
plt.xlabel('False Positive Rate')
###############################################################################
plt.figure(4)
plt.subplot(2,2,1)
false_positive_rate, true_positive_rate, thresholds = roc_curve(y_test, y_pred_NN1)
roc_auc = auc(false_positive_rate, true_positive_rate)
plt.title('Receiver Operating Characteristic NN1.67')
plt.plot(false_positive_rate, true_positive_rate, 'b',
label='AUC = %0.2f'% roc_auc)
plt.legend(loc='lower right')
plt.plot([0,1],[0,1],'r--')
plt.xlim([-0.1,1.2])
plt.ylim([-0.1,1.2])
plt.ylabel('True Positive Rate')
plt.xlabel('False Positive Rate')
###############################################################################
plt.subplot(2,2,2)
false_positive_rate, true_positive_rate, thresholds = roc_curve(y_test, y_pred_NN2)
roc_auc = auc(false_positive_rate, true_positive_rate)
plt.title('Receiver Operating Characteristic NN6.67')
plt.plot(false_positive_rate, true_positive_rate, 'b',
label='AUC = %0.2f'% roc_auc)
plt.legend(loc='lower right')
plt.plot([0,1],[0,1],'r--')
plt.xlim([-0.1,1.2])
plt.ylim([-0.1,1.2])
plt.ylabel('True Positive Rate')
plt.xlabel('False Positive Rate')
###############################################################################
plt.subplot(2,2,3)
false_positive_rate, true_positive_rate, thresholds = roc_curve(y_test, y_pred_NN3)
roc_auc = auc(false_positive_rate, true_positive_rate)
plt.title('Receiver Operating Characteristic NN30')
plt.plot(false_positive_rate, true_positive_rate, 'b',
label='AUC = %0.2f'% roc_auc)
plt.legend(loc='lower right')
plt.plot([0,1],[0,1],'r--')
plt.xlim([-0.1,1.2])
plt.ylim([-0.1,1.2])
plt.ylabel('True Positive Rate')
plt.xlabel('False Positive Rate')
plt.show()

# %% [markdown]
# # Plot the results

# %%
fig = plt.figure()
plt.rcParams['figure.figsize'] = (15, 10)
ax = fig.add_subplot(111)
accData = [metrics.accuracy_score(y_test, y_pred_neigh),
           metrics.accuracy_score(y_test, y_pred_svm_linear), 
           metrics.accuracy_score(y_test, y_pred_svm), 
           metrics.accuracy_score(y_test, y_pred_gtgini),
           metrics.accuracy_score(y_test, y_pred_dt_IG), 
           metrics.accuracy_score(y_test, y_pred_dt_BGKN),
           metrics.accuracy_score(y_test, y_pred_dt_BGDT), 
           metrics.accuracy_score(y_test, y_pred_dt_RF),
           metrics.accuracy_score(y_test, y_pred_dt_AD), 
           metrics.accuracy_score(y_test, y_pred_NB),
           metrics.accuracy_score(y_test, y_pred_dt_LDA), 
           metrics.accuracy_score(y_test, y_pred_dt_QDA),
           metrics.accuracy_score(y_test, y_pred_NN),
           metrics.accuracy_score(y_test, y_pred_NN1),
           metrics.accuracy_score(y_test, y_pred_NN2),
           metrics.accuracy_score(y_test, y_pred_NN3)]

PresionData = [metrics.precision_score(y_test, y_pred_neigh, average="binary"),
               metrics.precision_score(y_test, y_pred_svm_linear, average="binary"),
               metrics.precision_score(y_test, y_pred_svm, average="binary"),
               metrics.precision_score(y_test, y_pred_gtgini, average="binary"),
               metrics.precision_score(y_test, y_pred_dt_IG, average="binary"),
               metrics.precision_score(y_test, y_pred_dt_BGKN, average="binary"),
               metrics.precision_score(y_test, y_pred_dt_BGDT, average="binary"),
               metrics.precision_score(y_test, y_pred_dt_RF, average="binary"),
               metrics.precision_score(y_test, y_pred_dt_AD, average="binary"),
               metrics.precision_score(y_test, y_pred_NB, average="binary"),
               metrics.precision_score(y_test, y_pred_dt_LDA, average="binary"),
               metrics.precision_score(y_test, y_pred_dt_QDA, average="binary"),
               metrics.precision_score(y_test, y_pred_NN, average="binary"),
               metrics.precision_score(y_test, y_pred_NN1, average="binary"),
               metrics.precision_score(y_test, y_pred_NN2, average="binary"),
               metrics.precision_score(y_test, y_pred_NN3, average="binary")]
RecallData = [ metrics.recall_score(y_test, y_pred_neigh, average="binary"),
              metrics.recall_score(y_test, y_pred_svm_linear, average="binary"),
              metrics.recall_score(y_test, y_pred_svm, average="binary"),
              metrics.recall_score(y_test, y_pred_gtgini, average="binary"),
              metrics.recall_score(y_test, y_pred_dt_IG, average="binary"),
              metrics.recall_score(y_test, y_pred_dt_BGKN, average="binary"),
              metrics.recall_score(y_test, y_pred_dt_BGDT, average="binary"),
              metrics.recall_score(y_test, y_pred_dt_RF, average="binary"),
              metrics.recall_score(y_test, y_pred_dt_AD, average="binary"),
              metrics.recall_score(y_test, y_pred_NB, average="binary"),
              metrics.recall_score(y_test, y_pred_dt_LDA, average="binary"),
              metrics.recall_score(y_test, y_pred_dt_QDA, average="binary"),
              metrics.recall_score(y_test, y_pred_NN, average="binary"),
              metrics.recall_score(y_test, y_pred_NN1, average="binary"),
              metrics.recall_score(y_test, y_pred_NN2, average="binary"),
              metrics.recall_score(y_test, y_pred_NN3, average="binary")]

F1Data = [metrics.f1_score(y_test, y_pred_neigh, average="binary"),
          metrics.f1_score(y_test, y_pred_svm_linear, average="binary"),
          metrics.f1_score(y_test, y_pred_svm, average="binary"),
          metrics.f1_score(y_test, y_pred_gtgini, average="binary"),
          metrics.f1_score(y_test, y_pred_dt_IG, average="binary"),
          metrics.f1_score(y_test, y_pred_dt_BGKN, average="binary"),
          metrics.f1_score(y_test, y_pred_dt_BGDT, average="binary"),
          metrics.f1_score(y_test, y_pred_dt_RF, average="binary"),
          metrics.f1_score(y_test, y_pred_dt_AD, average="binary"),
          metrics.f1_score(y_test, y_pred_NB, average="binary"),
          metrics.f1_score(y_test, y_pred_dt_LDA, average="binary"),
          metrics.f1_score(y_test, y_pred_dt_QDA, average="binary"),
          metrics.f1_score(y_test, y_pred_NN, average="binary"),
          metrics.f1_score(y_test, y_pred_NN1, average="binary"),
          metrics.f1_score(y_test, y_pred_NN2, average="binary"),
          metrics.f1_score(y_test, y_pred_NN3, average="binary")]
N = len(accData)
## necessary variables
ind = np.arange(N)                # the x locations for the groups
width = 0.15                     # the width of the bars
## the bars
rects1 = ax.bar(ind, accData, width,
                color='black',
                #yerr=menStd,
                error_kw=dict(elinewidth=2,ecolor='red'))
rects2 = ax.bar(ind+width, F1Data, width,
                    color='red',
                    #yerr=womenStd,
                    error_kw=dict(elinewidth=2,ecolor='black'))
rects3 = ax.bar(ind+width+width, PresionData, width,
                    color='green',
                    #yerr=womenStd,
                    error_kw=dict(elinewidth=2,ecolor='blue'))
rects4 = ax.bar(ind+width+width+width, RecallData, width,
                    color='blue',
                    #yerr=womenStd,
                    error_kw=dict(elinewidth=2,ecolor='green'))
# axes and labels
ax.set_xlim(-width,len(ind)+width)
ax.set_ylim(0,0.95)
ax.set_ylabel('Score')
ax.set_title('Scores of different classifiers on Test Data')
xTickMarks = ['Knn', 'LSVM', 'SVM', 'DT_gini', 'DT_entorpy' ,
              'Bagging Knn' , 'Bagging DT' , 'Random Forest' , 'Ada Boost' ,
              'NB' , 'LDA' , 'QDA' , 'NN', 'NN1.67%R' , 'NN6.67%R' , 'NN30%R']
ax.set_xticks(ind+width)
xtickNames = ax.set_xticklabels(xTickMarks)
plt.setp(xtickNames, rotation=45, fontsize=10)
## add a legend
ax.legend( (rects1[0], rects2[0], rects3[0], rects4[0]), ('Acc.', 'F1' , 'Prec.' , 'Recall') , loc=8 )
plt.show()

# %% [markdown]
# # Compute Confusion Matrix

# %%
iris = datasets.load_iris()
from sklearn.metrics import confusion_matrix
plt.rcParams['figure.figsize'] = (15, 6)
def plot_confusion_matrix(cm, title='Confusion matrix', cmap=plt.cm.Blues):
    plt.imshow(cm, interpolation='nearest', cmap=cmap)
    plt.title(title)
    plt.colorbar()
    target_names=['Died' , 'Survied']
    tick_marks = np.arange(len(target_names))
    plt.xticks(tick_marks, target_names)
    plt.yticks(tick_marks, target_names)
    plt.tight_layout()
    plt.ylabel('True label')
    plt.xlabel('Predicted label')

# %% [markdown]
# ## Compute Confusion on Knn

# %%
cm = confusion_matrix(y_test, y_pred_neigh)
np.set_printoptions(precision=2)
print('Confusion matrix, without normalization')
print(cm)
plt.figure(1)
plt.subplot(2,2,1)

plot_confusion_matrix(cm)

# Normalize the confusion matrix by row (i.e by the number of samples
# in each class)
cm_normalized = cm.astype('float') / cm.sum(axis=1)[:, np.newaxis]
print('Normalized confusion matrix')
print(cm_normalized)
#plt.figure()
plt.subplot(2,2,2)

plot_confusion_matrix(cm_normalized, title='Normalized confusion matrix')

plt.show()
# Out:
# Confusion matrix, without normalization
# [[86 20]
#  [21 52]]
# Normalized confusion matrix
# [[ 0.81  0.19]
#  [ 0.29  0.71]]

# %% [markdown]
# ## Compute Confusion on LSVM

# %%
cm = confusion_matrix(y_test, y_pred_svm_linear)
np.set_printoptions(precision=2)
print('Confusion matrix, without normalization')
print(cm)
plt.figure(1)
plt.subplot(2,2,1)

plot_confusion_matrix(cm)

# Normalize the confusion matrix by row (i.e by the number of samples
# in each class)
cm_normalized = cm.astype('float') / cm.sum(axis=1)[:, np.newaxis]
print('Normalized confusion matrix')
print(cm_normalized)
#plt.figure()
plt.subplot(2,2,2)

plot_confusion_matrix(cm_normalized, title='Normalized confusion matrix')

plt.show()
# Out:
# Confusion matrix, without normalization
# [[89 17]
#  [24 49]]
# Normalized confusion matrix
# [[ 0.84  0.16]
#  [ 0.33  0.67]]

# %% [markdown]
# ## Compute Confusion on SVM

# %%
cm = confusion_matrix(y_test, y_pred_svm)
np.set_printoptions(precision=2)
print('Confusion matrix, without normalization')
print(cm)
plt.figure(1)
plt.subplot(2,2,1)

plot_confusion_matrix(cm)

# Normalize the confusion matrix by row (i.e by the number of samples
# in each class)
cm_normalized = cm.astype('float') / cm.sum(axis=1)[:, np.newaxis]
print('Normalized confusion matrix')
print(cm_normalized)
#plt.figure()
plt.subplot(2,2,2)

plot_confusion_matrix(cm_normalized, title='Normalized confusion matrix')

plt.show()
# Out:
# Confusion matrix, without normalization
# [[89 17]
#  [22 51]]
# Normalized confusion matrix
# [[ 0.84  0.16]
#  [ 0.3   0.7 ]]

# %% [markdown]
# ## Compute Confusion on DT with gini "CART"

# %%
cm = confusion_matrix(y_test, y_pred_gtgini)
np.set_printoptions(precision=2)
print('Confusion matrix, without normalization')
print(cm)
plt.figure(1)
plt.subplot(2,2,1)

plot_confusion_matrix(cm)

# Normalize the confusion matrix by row (i.e by the number of samples
# in each class)
cm_normalized = cm.astype('float') / cm.sum(axis=1)[:, np.newaxis]
print('Normalized confusion matrix')
print(cm_normalized)
#plt.figure()
plt.subplot(2,2,2)

plot_confusion_matrix(cm_normalized, title='Normalized confusion matrix')

plt.show()
# Out:
# Confusion matrix, without normalization
# [[62 44]
#  [22 51]]
# Normalized confusion matrix
# [[ 0.58  0.42]
#  [ 0.3   0.7 ]]

# %% [markdown]
# ## Compute Confusion on DT with entory "C5.0"

# %%
cm = confusion_matrix(y_test, y_pred_dt_IG)
np.set_printoptions(precision=2)
print('Confusion matrix, without normalization')
print(cm)
plt.figure(1)
plt.subplot(2,2,1)

plot_confusion_matrix(cm)

# Normalize the confusion matrix by row (i.e by the number of samples
# in each class)
cm_normalized = cm.astype('float') / cm.sum(axis=1)[:, np.newaxis]
print('Normalized confusion matrix')
print(cm_normalized)
#plt.figure()
plt.subplot(2,2,2)

plot_confusion_matrix(cm_normalized, title='Normalized confusion matrix')

plt.show()
# Out:
# Confusion matrix, without normalization
# [[84 22]
#  [24 49]]
# Normalized confusion matrix
# [[ 0.79  0.21]
#  [ 0.33  0.67]]

# %% [markdown]
# ## Compute Confusion on Bagging with Knn

# %%
cm = confusion_matrix(y_test, y_pred_dt_BGKN)
np.set_printoptions(precision=2)
print('Confusion matrix, without normalization')
print(cm)
plt.figure(1)
plt.subplot(2,2,1)

plot_confusion_matrix(cm)

# Normalize the confusion matrix by row (i.e by the number of samples
# in each class)
cm_normalized = cm.astype('float') / cm.sum(axis=1)[:, np.newaxis]
print('Normalized confusion matrix')
print(cm_normalized)
#plt.figure()
plt.subplot(2,2,2)

plot_confusion_matrix(cm_normalized, title='Normalized confusion matrix')

plt.show()
# Out:
# Confusion matrix, without normalization
# [[93 13]
#  [30 43]]
# Normalized confusion matrix
# [[ 0.88  0.12]
#  [ 0.41  0.59]]

# %% [markdown]
# ## Compute Confusion on Bagging with DT "CART"

# %%
cm = confusion_matrix(y_test, y_pred_dt_BGDT)
np.set_printoptions(precision=2)
print('Confusion matrix, without normalization')
print(cm)
plt.figure(1)
plt.subplot(2,2,1)

plot_confusion_matrix(cm)

# Normalize the confusion matrix by row (i.e by the number of samples
# in each class)
cm_normalized = cm.astype('float') / cm.sum(axis=1)[:, np.newaxis]
print('Normalized confusion matrix')
print(cm_normalized)
#plt.figure()
plt.subplot(2,2,2)

plot_confusion_matrix(cm_normalized, title='Normalized confusion matrix')

plt.show()
# Out:
# Confusion matrix, without normalization
# [[93 13]
#  [30 43]]
# Normalized confusion matrix
# [[ 0.88  0.12]
#  [ 0.41  0.59]]

# %% [markdown]
# ## Compute Confusion on Random Forest

# %%
cm = confusion_matrix(y_test, y_pred_dt_RF)
np.set_printoptions(precision=2)
print('Confusion matrix, without normalization')
print(cm)
plt.figure(1)
plt.subplot(2,2,1)

plot_confusion_matrix(cm)

# Normalize the confusion matrix by row (i.e by the number of samples
# in each class)
cm_normalized = cm.astype('float') / cm.sum(axis=1)[:, np.newaxis]
print('Normalized confusion matrix')
print(cm_normalized)
#plt.figure()
plt.subplot(2,2,2)

plot_confusion_matrix(cm_normalized, title='Normalized confusion matrix')

plt.show()
# Out:
# Confusion matrix, without normalization
# [[88 18]
#  [27 46]]
# Normalized confusion matrix
# [[ 0.83  0.17]
#  [ 0.37  0.63]]

# %% [markdown]
# ## Compute Confusion on Ada Boost

# %%
cm = confusion_matrix(y_test, y_pred_dt_AD)
np.set_printoptions(precision=2)
print('Confusion matrix, without normalization')
print(cm)
plt.figure(1)
plt.subplot(2,2,1)

plot_confusion_matrix(cm)

# Normalize the confusion matrix by row (i.e by the number of samples
# in each class)
cm_normalized = cm.astype('float') / cm.sum(axis=1)[:, np.newaxis]
print('Normalized confusion matrix')
print(cm_normalized)
#plt.figure()
plt.subplot(2,2,2)

plot_confusion_matrix(cm_normalized, title='Normalized confusion matrix')

plt.show()
# Out:
# Confusion matrix, without normalization
# [[82 24]
#  [21 52]]
# Normalized confusion matrix
# [[ 0.77  0.23]
#  [ 0.29  0.71]]

# %% [markdown]
# ## Compute Confusion on Naive Bayes

# %%
cm = confusion_matrix(y_test, y_pred_NB)
np.set_printoptions(precision=2)
print('Confusion matrix, without normalization')
print(cm)
plt.figure(1)
plt.subplot(2,2,1)

plot_confusion_matrix(cm)

# Normalize the confusion matrix by row (i.e by the number of samples
# in each class)
cm_normalized = cm.astype('float') / cm.sum(axis=1)[:, np.newaxis]
print('Normalized confusion matrix')
print(cm_normalized)
#plt.figure()
plt.subplot(2,2,2)

plot_confusion_matrix(cm_normalized, title='Normalized confusion matrix')

plt.show()
# Out:
# Confusion matrix, without normalization
# [[88 18]
#  [22 51]]
# Normalized confusion matrix
# [[ 0.83  0.17]
#  [ 0.3   0.7 ]]

# %% [markdown]
# ## Compute Confusion on LDA

# %%
cm = confusion_matrix(y_test, y_pred_dt_LDA)
np.set_printoptions(precision=2)
print('Confusion matrix, without normalization')
print(cm)
plt.figure(1)
plt.subplot(2,2,1)

plot_confusion_matrix(cm)

# Normalize the confusion matrix by row (i.e by the number of samples
# in each class)
cm_normalized = cm.astype('float') / cm.sum(axis=1)[:, np.newaxis]
print('Normalized confusion matrix')
print(cm_normalized)
#plt.figure()
plt.subplot(2,2,2)

plot_confusion_matrix(cm_normalized, title='Normalized confusion matrix')

plt.show()
# Out:
# Confusion matrix, without normalization
# [[89 17]
#  [24 49]]
# Normalized confusion matrix
# [[ 0.84  0.16]
#  [ 0.33  0.67]]

# %% [markdown]
# ## Compute Confusion on QDA

# %%
cm = confusion_matrix(y_test, y_pred_dt_QDA)
np.set_printoptions(precision=2)
print('Confusion matrix, without normalization')
print(cm)
plt.figure(1)
plt.subplot(2,2,1)

plot_confusion_matrix(cm)

# Normalize the confusion matrix by row (i.e by the number of samples
# in each class)
cm_normalized = cm.astype('float') / cm.sum(axis=1)[:, np.newaxis]
print('Normalized confusion matrix')
print(cm_normalized)
#plt.figure()
plt.subplot(2,2,2)

plot_confusion_matrix(cm_normalized, title='Normalized confusion matrix')

plt.show()
# Out:
# Confusion matrix, without normalization
# [[84 22]
#  [15 58]]
# Normalized confusion matrix
# [[ 0.79  0.21]
#  [ 0.21  0.79]]

# %% [markdown]
# ## Compute Confusion on NN

# %%
cm = confusion_matrix(y_test, y_pred_NN)
np.set_printoptions(precision=2)
print('Confusion matrix, without normalization')
print(cm)
plt.figure(1)
plt.subplot(2,2,1)

plot_confusion_matrix(cm)

# Normalize the confusion matrix by row (i.e by the number of samples
# in each class)
cm_normalized = cm.astype('float') / cm.sum(axis=1)[:, np.newaxis]
print('Normalized confusion matrix')
print(cm_normalized)
#plt.figure()
plt.subplot(2,2,2)

plot_confusion_matrix(cm_normalized, title='Normalized confusion matrix')

plt.show()
# Out:
# Confusion matrix, without normalization
# [[94 12]
#  [27 46]]
# Normalized confusion matrix
# [[ 0.89  0.11]
#  [ 0.37  0.63]]

# %% [markdown]
# ## Compute Confusion on NN 1.67% neurals removed

# %%
cm = confusion_matrix(y_test, y_pred_NN1)
np.set_printoptions(precision=2)
print('Confusion matrix, without normalization')
print(cm)
plt.figure(1)
plt.subplot(2,2,1)

plot_confusion_matrix(cm)

# Normalize the confusion matrix by row (i.e by the number of samples
# in each class)
cm_normalized = cm.astype('float') / cm.sum(axis=1)[:, np.newaxis]
print('Normalized confusion matrix')
print(cm_normalized)
#plt.figure()
plt.subplot(2,2,2)

plot_confusion_matrix(cm_normalized, title='Normalized confusion matrix')

plt.show()
# Out:
# Confusion matrix, without normalization
# [[94 12]
#  [24 49]]
# Normalized confusion matrix
# [[ 0.89  0.11]
#  [ 0.33  0.67]]

# %% [markdown]
# ## Compute Confusion on NN 6.67% neurals removed

# %%
cm = confusion_matrix(y_test, y_pred_NN2)
np.set_printoptions(precision=2)
print('Confusion matrix, without normalization')
print(cm)
plt.figure(1)
plt.subplot(2,2,1)

plot_confusion_matrix(cm)

# Normalize the confusion matrix by row (i.e by the number of samples
# in each class)
cm_normalized = cm.astype('float') / cm.sum(axis=1)[:, np.newaxis]
print('Normalized confusion matrix')
print(cm_normalized)
#plt.figure()
plt.subplot(2,2,2)

plot_confusion_matrix(cm_normalized, title='Normalized confusion matrix')

plt.show()
# Out:
# Confusion matrix, without normalization
# [[93 13]
#  [22 51]]
# Normalized confusion matrix
# [[ 0.88  0.12]
#  [ 0.3   0.7 ]]

# %% [markdown]
# ### Compute Confusion on NN 30% neurals removed

# %%
### cm = confusion_matrix(y_test, y_pred_NN3)
np.set_printoptions(precision=2)
print('Confusion matrix, without normalization')
print(cm)
plt.figure(1)
plt.subplot(2,2,1)

plot_confusion_matrix(cm)

# Normalize the confusion matrix by row (i.e by the number of samples
# in each class)
cm_normalized = cm.astype('float') / cm.sum(axis=1)[:, np.newaxis]
print('Normalized confusion matrix')
print(cm_normalized)
#plt.figure()
plt.subplot(2,2,2)

plot_confusion_matrix(cm_normalized, title='Normalized confusion matrix')

plt.show()
# Out:
# Confusion matrix, without normalization
# [[93 13]
#  [22 51]]
# Normalized confusion matrix
# [[ 0.88  0.12]
#  [ 0.3   0.7 ]]
